# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import urllib.request

searchKey = input('검색 키워드 입력:')

driver = webdriver.Chrome('D:\workspace\jupyter\Chrome_driver\chromedriver.exe')
driver.get("https://www.google.co.kr/imghp?hl=ko&tab=wi&authuser=0&ogbl")
elem = driver.find_element("name", "q")

elem.send_keys(searchKey)
elem.send_keys(Keys.RETURN)

SCROLL_PAUSE_TIME = 1
# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)
    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        try:
            driver.find_element(By.CSS_SELECTOR, ".mye4qd").click()
        except:
            break
    last_height = new_height

images = driver.find_elements(By.CSS_SELECTOR, ".rg_i.Q4LuWd")
count = 1
for image in images:
    try:
        image.click()
        time.sleep(0.5)
        
        imgUrl = driver.find_element(
			By.XPATH,
			'//*[@id="Sva75c"]/div[2]/div[2]/div[2]/div[2]/c-wiz/div/div/div/div[3]/div[1]/a/img[1]'
        ).get_attribute("src")

        opener = urllib.request.build_opener()
        opener.addheaders = [
            ('User-Agent',
             'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1941.0 Safari/537.36')
        ]
        urllib.request.install_opener(opener)
        urllib.request.urlretrieve(imgUrl, f'./imgs/{searchKey}{str(count)}.jpg')
        count = count + 1
    except Exception as e:
        print('e : ', e)
        pass

driver.close()
# Out:
# 검색 키워드 입력:웃는 사람
# e :  <urlopen error [WinError 10054] 현재 연결은 원격 호스트에 의해 강제로 끊겼습니다>
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="258" height="196" alt="얼굴을 보면 당신의 인생이 보인다" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR0k-dBCBn_n4TDQ_9m5JMEVyvITM6nzPX7oQ&amp;usqp=CAU"> is not clickable at point (207, 854). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="220" height="220" alt="웃는 사람 아이콘 미소에 대한 스톡 벡터 아트 및 기타 이미지 - 미소, 백인종, 벡터 - iStock" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSd4RE_uqYsdRNUibgGN46k7UERs4022t3V5w&amp;usqp=CAU"> is not clickable at point (207, 852). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="Sva75c"]/div[2]/div[2]/div[2]/div[2]/c-wiz/div/div/div/div[3]/div[1]/a/img[1]"}
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="160" height="205" alt="웃는 사람(여성)의 일러스트 – 무료 일러스트 소재집 KuKuKeKe" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSZX197OYNUc8AUdG6Si8RRAsA6FWfKNu_syw&amp;usqp=CAU"> is not clickable at point (103, 856). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="183" height="275" alt="웃는 사람이 성공한다 - 예스24" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQPZ7OpihqdRCqii8OTmpy1q6yvYjxtHdjQjA&amp;usqp=CAU"> is not clickable at point (299, 852). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="152" height="196" alt="웃는 사람 (남성)의 그림 – 무료 일러스트 소재집 KuKuKeKe" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ4IcTjHThE0kJcnfHlI9Isq9Y7yoX3va6Zhw&amp;usqp=CAU"> is not clickable at point (96, 858). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="202" height="202" alt="116,800개 이상의 사람 같은 웃는 얼굴 일러스트, Royalty-Free 벡터 그래픽 및 클립 아트 - iStock" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRlLmVbkcxSzvmfWdXh5k3Ju7Q5mxcTm1fu4g&amp;usqp=CAU"> is not clickable at point (293, 857). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="212" height="201" alt="웃는 사람에게 복이 온다 :: 우버 人사이트" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT67KY_5YKW2zlMqGByXh3t-XvTHC7XwzMlRg&amp;usqp=CAU"> is not clickable at point (207, 857). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="Sva75c"]/div[2]/div[2]/div[2]/div[2]/c-wiz/div/div/div/div[3]/div[1]/a/img[1]"}
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width
src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSPR-DWRRcV4VQc9-Tn5RawiqPTjlY4F-I_6Q&amp;usqp=CAU"> is not clickable at point (290, 97). Other element would receive the click: <img src="data:image/jpeg;base64,..." data-deferred="1" alt="" class="rHLoR" width="48" height="48" data-iml="710.1000000238419" data-atf="true">
#   (Session info: chrome=118.0.5993.70)
# e :  Message: element click intercepted: Element <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQOrdt4iC5YFHErbo-BUTWv1t_7fUqBDmgm0EkPiGeCP7xjusp3n1mUFdrz4DLIXTN5qxc&amp;usqp=CAU" class="rg_i Q4LuWd" jsname="Q4LuWd" width="145" height="182" alt="잘 웃는 사람이 되자 - HANDANANG" data-iml="4051.3000000715256"> is not clickable at point (321, 91). Other element would receive the click: <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTMCBc97ztI4_SCciYy0XClYG1-ppLqRtHF6pxxo9cRhDXnALuZYJsCkhuMEfjvkS80NNQ&amp;usqp=CAU" class="rg_i Q4LuWd" jsname="Q4LuWd" width="300" height="169" alt="비장의무비]'집'이 없어 우는 대신, '길'에서 웃는 사람들 - 〈노매드랜드〉 - 시사IN" data-iml="3947.3000000715256">
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ_R2YLopmHkrbuJin-IIOOtSDy9XFUEWZZ469B370iPz2zkiBgV-i5pwjdOPHMm8Ko8HU&amp;usqp=CAU" class="rg_i Q4LuWd" jsname="Q4LuWd" width="299" height="169" alt="마지막에 웃는 사람 | 한국경제" data-iml="3947.7000000476837"> is not clickable at point (207, 84). Other element would receive the click: <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR2HvlVeNsxUCXKgBfwkf-dGcbFgE43pJpN6as5SQ_ibQCKCTPvcembDYmeT11u7DFkRnU&amp;usqp=CAU" class="rg_i Q4LuWd" jsname="Q4LuWd" width="300" height="169" alt="튀르키예, 최저임금 50% 인상에도 웃는 사람 없는 이유 | YTN" data-iml="4039.9000000953674">
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSVb3B1YVXdcnEMnaVrPODPwa0hs_Rf5IXuht8ztmceHeJOiAO4YTG24964zsn1qneprl8&amp;usqp=CAU" class="rg_i Q4LuWd" jsname="Q4LuWd" width="261" height="180" alt="맘을 다해 웃는 사람은 귀엽다." data-iml="3947.3000000715256"> is not clickable at point (207, 90). Other element would receive the click: <a data-ved="2ahUKEwiWqd_jjZKCAxWZwGEKHbc-AVQQ4lYoAXoECAEQLQ" aria-label="밝게" jslog="11106" href="/search?q=%EC%9B%83%EB%8A%94+%EC%82%AC%EB%9E%8C&amp;tbm=isch&amp;hl=ko&amp;chips=q:%EC%9B%83%EB%8A%94+%EC%82%AC%EB%9E%8C,g_1:%EB%B0%9D%EA%B2%8C:0W0POHVkMf4%3D&amp;authuser=0&amp;bih=882&amp;biw=929&amp;sa=X&amp;ved=2ahUKEwiWqd_jjZKCAxWZwGEKHbc-AVQQ4lYoAXoECAEQLQ" data-navigation="server" class="ZZ7G7b A6Smgb">...</a>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRqxznu7yQzN63OZ6Igq4o2wXUKCdS7nOS42l8o5HPxvk5bMPhHUmU8v8J8heJhEPZ48Wc&amp;usqp=CAU" class="rg_i Q4LuWd" jsname="Q4LuWd" width="266" height="190" alt="교차 어깨를 가진 웃는 사람들의 그룹의 벡터 일러스트 레이 션 | 프리미엄 벡터" data-iml="3946.7000000476837"> is not clickable at point (207, 862). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="152" height="228" alt="비누 거품으로 웃는 사람 사진 무료 다운로드 - Lovepik" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSrG6_G-vHBbHcP7MpucubYzXAn_dWDD1-fXw&amp;usqp=CAU"> is not clickable at point (110, 845). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="267" height="190" alt="Pin on 명언" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSRK_ksXMlxAtQflKXighpmLmdxmPy67FFpXQ&amp;usqp=CAU"> is not clickable at point (207, 857). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="176" height="237" alt="배고픔과 웃는 사람(여자)의 일러스트 – 무료 일러스트 소재집 KuKuKeKe" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRLB0I8ZVLeUoH6rgUGf8cmYEwH42Zp-ozilA&amp;usqp=CAU"> is not clickable at point (207, 848). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  <urlopen error [SSL: UNSAFE_LEGACY_RENEGOTIATION_DISABLED] unsafe legacy renegotiation disabled (_ssl.c:1006)>
# e :  Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="Sva75c"]/div[2]/div[2]/div[2]/div[2]/c-wiz/div/div/div/div[3]/div[1]/a/img[1]"}
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="225" height="225" alt="젊은 남자 웃는 사람 백인 매력적인 초상화 쾌활한 남성 캐릭터 벡터 일러스트 건강한 생활방식에 대한 스톡 벡터 아트 및 기타 이미지 -  건강한 생활방식, 공원, 귀여운 - iStock" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT_1JUwQDlcivWocIovdJxgB58sziXiFqzGQA&amp;usqp=CAU"> is not clickable at point (207, 853). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="223" height="192" alt="행복, 자유, 운동, 웃는 사람들... 웃고 스톡 벡터(로열티 프리) 1242881914 | Shutterstock" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTkBRZjK7QMjmKqmaG_dLZR6_ePs8FqvLGvOA&amp;usqp=CAU"> is not clickable at point (207, 856). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="198" height="198" alt="무료로 다운로드 가능한 웃는 사람 벡터 &amp; 일러스트 | Freepik" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSYixnUk_qhm338AAnktFeYLwUtqN7XGjgUCQ&amp;usqp=CAU"> is not clickable at point (207, 858). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="149" height="201" alt="웃는 사람과 낙관적 인 사람 (여성)의 그림 – 무료 일러스트 소재집 KuKuKeKe" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSdX0YQlSWvuz5CewVLgjbs-CLKi80-NHZEqw&amp;usqp=CAU"> is not clickable at point (94, 857). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="205" height="205" alt="원 안에 아시아 만화 웃는 사람 벡터, 흰색 바탕에 귀여운 의료 보조원을 묘사한 직계 아이콘, Flaticon 및 드리블에 의한 벡터  일러스트, 비핸스 Hd PNG, 일러스트 및 벡터 에 대한 무료 다운로드 -" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTQuJFk1H2sdalWliRGa7BfK2Ocmo_bq2RGwg&amp;usqp=CAU"> is not clickable at point (291, 856). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="198" height="198" alt="웃는 사람들 아바타 세트 다른 남성과 여성 캐릭터 컬렉션 일러스트 PNG AI 무료 다운로드 - Pikbest" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR2pjg8AOfnXE__e3Vo3iGdL5ECbqqAEC9edg&amp;usqp=CAU"> is not clickable at point (207, 859). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="Sva75c"]/div[2]/div[2]/div[2]/div[2]/c-wiz/div/div/div/div[3]/div[1]/a/img[1]"}
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="155" height="198" alt="웃는 사람 (남성)의 그림 – 무료 일러스트 소재집 KuKuKeKe" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSROQxJdE9v0eMcWj5ag8uTOhBL8lXtc6EHrg&amp;usqp=CAU"> is not clickable at point (207, 856). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
# e :  Message: element click intercepted: Element <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTpIZ7G2NWZtLH86OgdEpLNg5cQmiirRsfXFaZ6rE9mjzwiGol1iCPklCBPJGdtLunkqDE&amp;usqp=CAU" class="rg_i Q4LuWd" jsname="Q4LuWd" width="225" height="225" alt="웃는사람 - 웃는사람 added a new photo." data-iml="5339.200000047684"> is not clickable at point (207, 852). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="Sva75c"]/div[2]/div[2]/div[2]/div[2]/c-wiz/div/div/div/div[3]/div[1]/a/img[1]"}
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="259" height="195" alt="매일 오후 11시에 채팅을 치는 빌런을 부검했더니... ㄷㄷ - YouTube" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTFQAzJVYO3UR3lQZ_sZEhtQgESckwBxe8Q8g&amp;usqp=CAU"> is not clickable at point (207, 859). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="Sva75c"]/div[2]/div[2]/div[2]/div[2]/c-wiz/div/div/div/div[3]/div[1]/a/img[1]"}
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="164" height="218" alt="웃는사람 이미지 - Freepik에서 무료 다운로드" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ9Yz-l8PDmy3A0knSfCn2Imo2mnFKFYQ6pLQ&amp;usqp=CAU"> is not clickable at point (102, 859). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="275" height="184" alt="교차 손가락으로 웃는 사람 행운 행운입니다 흰색과 빨간색 셔츠를 입고 젊은 라틴 아메리카 사람 흰색 배경입니다 T 셔츠에 대한 스톡  사진 및 기타 이미지 - iStock" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSGDenGaCDZWYKn-q8P3rMoAfUr5XSBe6H5Jw&amp;usqp=CAU"> is not clickable at point (207, 862). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="Sva75c"]/div[2]/div[2]/div[2]/div[2]/c-wiz/div/div/div/div[3]/div[1]/a/img[1]"}
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="167" height="205" alt="뱃속을 잡고 웃는 사람(할아버지)의 그림 – 무료 일러스트 소재집 KuKuKeKe" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTyNFPloNTidWxQZ0xCxE9xdysy1HqjTcODzQ&amp;usqp=CAU"> is not clickable at point (207, 856). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="Sva75c"]/div[2]/div[2]/div[2]/div[2]/c-wiz/div/div/div/div[3]/div[1]/a/img[1]"}
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="Sva75c"]/div[2]/div[2]/div[2]/div[2]/c-wiz/div/div/div/div[3]/div[1]/a/img[1]"}
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="115" height="186" alt="29 웃음 : 네이버 포스트" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQpmUKNNMRSLIWUeA-YLyd2klCMEqCPIn8sgA&amp;usqp=CAU"> is not clickable at point (108, 859). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="Sva75c"]/div[2]/div[2]/div[2]/div[2]/c-wiz/div/div/div/div[3]/div[1]/a/img[1]"}
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="142" height="212" alt="포장 도로에 서있는 동안 웃는 사람의 흑백 사진 · 무료 스톡 사진" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTd4sysMcOpBMJVaIRht2-CzwWuRuoNGSaFOQ&amp;usqp=CAU"> is not clickable at point (93, 859). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="Sva75c"]/div[2]/div[2]/div[2]/div[2]/c-wiz/div/div/div/div[3]/div[1]/a/img[1]"}
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="247" height="192" alt="영화관에서 영화를 보면서 웃는 사람들의 일러스트 – 무료 일러스트 소재집 KuKuKeKe" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRtH3LMvwNNCis-3rPklaUU_8ApYTpm83xLvg&amp;usqp=CAU"> is not clickable at point (207, 859). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="200" height="200" alt="웃을 줄 아는 사람" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTOSlMBUx3gblwO8-NUXNkTgjCKHKld5koWlQ&amp;usqp=CAU"> is not clickable at point (207, 857). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
#
# e :  Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="215" height="215" alt="좋은글 명언] 잘 웃는 사람이 되는 비결" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcREwvgqSy02VmNmcYgi6VRyVzusIrfr6KU6nQ&amp;usqp=CAU"> is not clickable at point (207, 845). Other element would receive the click: <div jsname="r5xl4" class="islrc" role="list" style="width: 394px;">...</div>
#   (Session info: chrome=118.0.5993.70)
